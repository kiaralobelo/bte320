# %% [markdown]
# <a href="https://colab.research.google.com/github/kiaralobelo/bte320/blob/main/in_class_assignment_jan23.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
enter sales ($): 12000
sales: $12000.0
COGS: $4800.0
gross profit: $7200

# %%
sales = float(input("Sales: $"))

cogs = 0.4*sales
gross_profit= sales-cogs

print(f"Sales: {sales}$")
print(f"cost of goods sold: {cogs}$")
print(f"gross profit: {gross_profit}$")
tax_rate = float(input("tax rate: %"))
tax = gross_profit*(tax_rate/100)
net_income = gross_profit-tax
print(f"taxes: {tax}$")
print(f"net income: {net_income}$")
# Out:
# Sales: $12000
# Sales: 12000.0$
# cost of goods sold: 4800.0$
# gross profit: 7200.0$
# tax rate: %30
# taxes: 2160.0$
# net income: 5040.0$
